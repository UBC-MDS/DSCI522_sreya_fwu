# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
crime_12_17 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv',sep=',', index_col=False, dtype='unicode')
crime_12_17.head(5)
# Out:
#   Unnamed: 0        ID Case Number                    Date  \
# 0          3  10508693    HZ250496  05/03/2016 11:40:00 PM
# 1         89  10508695    HZ250409  05/03/2016 09:40:00 PM
# 2        197  10508697    HZ250503  05/03/2016 11:31:00 PM
# 3        673  10508698    HZ250424  05/03/2016 10:10:00 PM
# 4        911  10508699    HZ250455  05/03/2016 10:00:00 PM
#
#                  Block  IUCR            Primary Type              Description  \
# 0   013XX S SAWYER AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 1   061XX S DREXEL AVE  0486                 BATTERY  DOMESTIC BATTERY SIMPLE
# 2  053XX W CHICAGO AVE  0470  PUBLIC PEACE VIOLATION         RECKLESS CONDUCT
# 3    049XX W FULTON ST  0460                 BATTERY                   SIMPLE
# 4    003XX N LOTUS AVE  0820                   THEFT           $500 AND UNDER
#
#   Location Description Arrest              ...                Ward  \
# 0            APARTMENT   True              ...                24.0
# ...

# %%
crime_12_17 = pd.read_csv('Chicago_Crimes_2012_to_2017.csv',sep=',', index_col=False, dtype='unicode')
crime_12_17.head(5)
new_crime = crime_12_17.drop(crime_12_17.columns[[0, 1, 2, 4, 5, 7, 10, 11, 12, 13, 14, 15, 16, 17, 19, 20, 21, 22]], axis=1)
new_crime.head(5)
#new_crime[(new_crime[Year]>2013)]
#new_crime.to_csv('new_crime2.csv', sep='\t')
# Out:
#                      Date            Primary Type Location Description Arrest  \
# 0  05/03/2016 11:40:00 PM                 BATTERY            APARTMENT   True
# 1  05/03/2016 09:40:00 PM                 BATTERY            RESIDENCE  False
# 2  05/03/2016 11:31:00 PM  PUBLIC PEACE VIOLATION               STREET  False
# 3  05/03/2016 10:10:00 PM                 BATTERY             SIDEWALK  False
# 4  05/03/2016 10:00:00 PM                   THEFT            RESIDENCE  False
#
#    Year
# 0  2016
# 1  2016
# 2  2016
# 3  2016
# 4  2016

# %%
crime_12_17[(crime_12_17[Year]>2013)]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-07d416c73752> in <module>()
# ----> 1 crime_12_17[(crime_12_17[Year]>2013)]
#
# NameError: name 'Year' is not defined
